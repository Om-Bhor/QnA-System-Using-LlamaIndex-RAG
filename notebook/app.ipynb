# %%
import fitz

pdf = fitz.open("../Data/M5.pdf")

print("Pages:", len(pdf))

text = pdf[0].get_text()

print("Characters:", len(text))

print(text[:500])
# Out:
# Pages: 9
# Characters: 663
# Module 5: Unsupervised Learning
# K means Clustering
#  K-Means Clustering groups similar data points into clusters without needing
# labelled data.
#  Works by grouping points based on distance to cluster centres.
#  Commonly used in customer segmentation, image compression, and pattern
# discovery
#  Useful when you need structure from raw, unorganized data
# Working of K-Means Clustering
#
#
#
#
#
#  "𝒌" Represents the number of groups or clusters we want to classify our items into.
#  The algo
